# %%
from astropy.table import Table

# %%
csv = Table.read('/Users/jmedina/Downloads/MyCode/exocat.csv', format='ascii')
print(len(csv))
csv[10]
# Out:
# 54
# <Row index=10>
# Exoplanet Program   Status  SpElement StPhase EndPhase Norbits      Date     ScanDirection ScanRate  AltName
#    str9    int64    str14      str4   float64 float64   int64      int64          str9     float64    str23
# --------- ------- --------- --------- ------- -------- ------- ------------- ------------- -------- ---------
# HD-149026   14260 completed      G141  0.9312   0.9433       5 1470321931554     Roundtrip      0.7 HD-149026

# %%
for idx in range(0, len(csv)):
    row = csv[idx]
    print('<tr>')
    print('<td class="tg-y698">{}</td>'.format(row[0]))
    print('<td class="tg-0pky">{}</td>'.format(str(row[1])))
    print('<td class="tg-0pky">{}</td>'.format(str(row[2])))
    print('<td class="tg-0pky">{}</td>'.format(str(row[3])))
    print('<td class="tg-0pky">{}</td>'.format(str(row[4])))
    print('<td class="tg-0pky">{}</td>'.format(str(row[5])))
    print('<td class="tg-0pky">{}</td>'.format(str(row[6])))
    print('<td class="tg-0pky">{}</td>'.format(str(row[7])))
    print('<td class="tg-0pky">{}</td>'.format(str(row[8])))
    print('<td class="tg-0pky">{}</td>'.format(str(row[9])))
    print('<td class="tg-0pky">{}</td>'.format(str(row[10])))
    print('</tr>')
# Out:
# <tr>
# <td class="tg-y698">WASP-96</td>
# <td class="tg-0pky">15469</td>
# <td class="tg-0pky">failed</td>
# <td class="tg-0pky">G102</td>
# <td class="tg-0pky">0.937</td>
# <td class="tg-0pky">0.94</td>
# <td class="tg-0pky">5</td>
# <td class="tg-0pky">1534111305990</td>
# <td class="tg-0pky">Forward</td>
# <td class="tg-0pky">0.013</td>
# <td class="tg-0pky">2MASS-J00041112-4721382</td>
# </tr>
# <tr>
# <td class="tg-y698">WASP-96</td>
# <td class="tg-0pky">15469</td>
# <td class="tg-0pky">implementation</td>
# <td class="tg-0pky">G102</td>
# <td class="tg-0pky">0.937</td>
# <td class="tg-0pky">0.94</td>
# <td class="tg-0pky">5</td>
# <td class="tg-0pky">1534111305990</td>
# <td class="tg-0pky">Forward</td>
# <td class="tg-0pky">0.013</td>
# <td class="tg-0pky">2MASS-J00041112-4721382</td>
# </tr>
# <tr>
# <td class="tg-y698">WASP-96</td>
# <td class="tg-0pky">15469</td>
# <td class="tg-0pky">implementation</td>
# <td class="tg-0pky">G141</td>
# <td class="tg-0pky">0.937</td>
# ...
